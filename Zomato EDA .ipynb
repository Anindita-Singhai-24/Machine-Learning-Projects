# %%
import numpy as np, pandas as pd, matplotlib.pyplot as plt
# %matplotlib inline

# %%
zomato=pd.read_csv("D:/machine learning/zomato/zomato_restaurants_in_India.csv")

# %%
zomato.head()
# Out:
#     res_id                            name      establishment  \
# 0  3400299                     Bikanervala    ['Quick Bites']
# 1  3400005  Mama Chicken Mama Franky House    ['Quick Bites']
# 2  3401013                   Bhagat Halwai    ['Quick Bites']
# 3  3400290                   Bhagat Halwai    ['Quick Bites']
# 4  3401744     The Salt Cafe Kitchen & Bar  ['Casual Dining']
#
#                                                  url  \
# 0  https://www.zomato.com/agra/bikanervala-khanda...
# 1  https://www.zomato.com/agra/mama-chicken-mama-...
# 2  https://www.zomato.com/agra/bhagat-halwai-2-sh...
# 3  https://www.zomato.com/agra/bhagat-halwai-civi...
# 4  https://www.zomato.com/agra/the-salt-cafe-kitc...
#
#                                              address  city  city_id  \
# 0  Kalyani Point, Near Tulsi Cinema, Bypass Road,...  Agra       34
# 1        Main Market, Sadar Bazaar, Agra Cantt, Agra  Agra       34
# 2  62/1, Near Easy Day, West Shivaji Nagar, Goalp...  Agra       34
# 3  Near Anjana Cinema, Nehru Nagar, Civil Lines, ...  Agra       34
# 4        1C,3rd Floor, Fatehabad Road, Tajganj, Agra  Agra       34
#
#       locality   latitude  longitude  ... price_range  currency  \
# 0     Khandari  27.211450  78.002381  ...           2       Rs.
# 1   Agra Cantt  27.160569  78.011583  ...           2       Rs.
# 2     Shahganj  27.182938  77.979684  ...           1       Rs.
# 3  Civil Lines  27.205668  78.004799  ...           1       Rs.
# 4      Tajganj  27.157709  78.052421  ...           3       Rs.
#
#                                           highlights aggregate_rating  \
# 0  ['Lunch', 'Takeaway Available', 'Credit Card',...              4.4
# 1  ['Delivery', 'No Alcohol Available', 'Dinner',...              4.4
# 2  ['No Alcohol Available', 'Dinner', 'Takeaway A...              4.2
# 3  ['Takeaway Available', 'Credit Card', 'Lunch',...              4.3
# 4  ['Lunch', 'Serves Alcohol', 'Cash', 'Credit Ca...              4.9
#
#   rating_text  votes  photo_count opentable_support delivery  takeaway
# 0   Very Good    814          154               0.0       -1        -1
# 1   Very Good   1203          161               0.0       -1        -1
# 2   Very Good    801          107               0.0        1        -1
# 3   Very Good    693          157               0.0        1        -1
# 4   Excellent    470          291               0.0        1        -1
#
# [5 rows x 26 columns]

# %%
zomato.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 211944 entries, 0 to 211943
# Data columns (total 26 columns):
# res_id                  211944 non-null int64
# name                    211944 non-null object
# establishment           211944 non-null object
# url                     211944 non-null object
# address                 211810 non-null object
# city                    211944 non-null object
# city_id                 211944 non-null int64
# locality                211944 non-null object
# latitude                211944 non-null float64
# longitude               211944 non-null float64
# zipcode                 48757 non-null object
# country_id              211944 non-null int64
# locality_verbose        211944 non-null object
# cuisines                210553 non-null object
# timings                 208070 non-null object
# average_cost_for_two    211944 non-null int64
# price_range             211944 non-null int64
# currency                211944 non-null object
# highlights              211944 non-null object
# aggregate_rating        211944 non-null float64
# rating_text             211944 non-null object
# votes                   211944 non-null int64
# photo_count             211944 non-null int64
# opentable_support       211896 non-null float64
# delivery                211944 non-null int64
# takeaway                211944 non-null int64
# dtypes: float64(4), int64(9), object(13)
# memory usage: 42.0+ MB

# %%
zomato=zomato.drop(columns=["zipcode",'url','address', 'city','city_id','locality','latitude','longitude','opentable_support','timings'])

# %%
zomato
# Out:
#           res_id                            name      establishment  \
# 0        3400299                     Bikanervala    ['Quick Bites']
# 1        3400005  Mama Chicken Mama Franky House    ['Quick Bites']
# 2        3401013                   Bhagat Halwai    ['Quick Bites']
# 3        3400290                   Bhagat Halwai    ['Quick Bites']
# 4        3401744     The Salt Cafe Kitchen & Bar  ['Casual Dining']
# ...          ...                             ...                ...
# 211939   3202251  Kali Mirch Cafe And Restaurant  ['Casual Dining']
# 211940   3200996                      Raju Omlet    ['Quick Bites']
# 211941  18984164                The Grand Thakar  ['Casual Dining']
# 211942   3201138                          Subway    ['Quick Bites']
# 211943  18879846     Freshco's - The Health Cafe           ['Café']
#
#         country_id      locality_verbose  \
# 0                1        Khandari, Agra
# 1                1      Agra Cantt, Agra
# 2                1        Shahganj, Agra
# 3                1     Civil Lines, Agra
# 4                1         Tajganj, Agra
# ...            ...                   ...
# 211939           1   Fatehgunj, Vadodara
# 211940           1  Karelibaug, Vadodara
# 211941           1    Alkapuri, Vadodara
# 211942           1       Akota, Vadodara
# 211943           1    Vadiwadi, Vadodara
#
#                                                  cuisines  \
# 0       North Indian, South Indian, Mithai, Street Foo...
# 1       North Indian, Mughlai, Rolls, Chinese, Fast Fo...
# 2                                       Fast Food, Mithai
# 3               Desserts, Bakery, Fast Food, South Indian
# 4                      North Indian, Continental, Italian
# ...                                                   ...
# 211939                                       North Indian
# 211940                                          Fast Food
# 211941                    Gujarati, North Indian, Chinese
# 211942                         Fast Food, Sandwich, Salad
# 211943                         Cafe, Healthy Food, Coffee
#
#         average_cost_for_two  price_range currency  \
# 0                        700            2      Rs.
# 1                        600            2      Rs.
# 2                        300            1      Rs.
# 3                        300            1      Rs.
# 4                       1000            3      Rs.
# ...                      ...          ...      ...
# 211939                   600            2      Rs.
# 211940                   300            1      Rs.
# 211941                   700            2      Rs.
# 211942                   500            2      Rs.
# 211943                   600            2      Rs.
#
#                                                highlights  aggregate_rating  \
# 0       ['Lunch', 'Takeaway Available', 'Credit Card',...               4.4
# 1       ['Delivery', 'No Alcohol Available', 'Dinner',...               4.4
# 2       ['No Alcohol Available', 'Dinner', 'Takeaway A...               4.2
# 3       ['Takeaway Available', 'Credit Card', 'Lunch',...               4.3
# 4       ['Lunch', 'Serves Alcohol', 'Cash', 'Credit Ca...               4.9
# ...                                                   ...               ...
# 211939  ['Dinner', 'Cash', 'Lunch', 'Delivery', 'Indoo...               4.1
# 211940  ['Dinner', 'Cash', 'Takeaway Available', 'Debi...               4.1
# 211941  ['Dinner', 'Cash', 'Debit Card', 'Lunch', 'Tak...               4.0
# 211942  ['Dinner', 'Delivery', 'Credit Card', 'Lunch',...               3.7
# 211943  ['Dinner', 'Cash', 'Takeaway Available', 'Debi...               4.0
#
#        rating_text  votes  photo_count  delivery  takeaway
# 0        Very Good    814          154        -1        -1
# 1        Very Good   1203          161        -1        -1
# 2        Very Good    801          107         1        -1
# 3        Very Good    693          157         1        -1
# 4        Excellent    470          291         1        -1
# ...            ...    ...          ...       ...       ...
# 211939   Very Good    243           40        -1        -1
# 211940   Very Good    187           40         1        -1
# 211941   Very Good    111           38        -1        -1
# 211942        Good    128           34         1        -1
# 211943   Very Good     93           53         1        -1
#
# [211944 rows x 16 columns]

# %%
temp=zomato.highlights[0]
temp
# Out:
# "['Lunch', 'Takeaway Available', 'Credit Card', 'Dinner', 'Cash', 'Air Conditioned', 'Indoor Seating', 'Pure Veg']"

# %%
def highlights(x):
    x=x.split("'")
    y=[]
    for i in range(0,len(x)):
        if i%2!=0:
            y.append(x[i])
    return y
highlights(temp)
# Out:
# ['Lunch',
#  'Takeaway Available',
#  'Credit Card',
#  'Dinner',
#  'Cash',
#  'Air Conditioned',
#  'Indoor Seating',
#  'Pure Veg']

# %%
zomato.highlights=zomato.highlights.apply(highlights)

# %%
zomato['highlights_count']=zomato.highlights.apply(lambda x:len(x))

# %%
total_highlights= set()
for i in zomato.highlights:
    total_highlights.update(i)

# %%
len(total_highlights)
# Out:
# 103

# %%
zomato.establishment.value_counts()
# Out:
# ['Quick Bites']        64390
# ['Casual Dining']      61808
# ['Café']               22760
# ['Bakery']              8282
# ['Dessert Parlour']     7961
# ['Bar']                 6553
# ['Fine Dining']         6401
# ['Sweet Shop']          6103
# ['Beverage Shop']       5571
# []                      4827
# ['Dhaba']               2939
# ['Lounge']              2761
# ['Food Court']          2722
# ['Kiosk']               1829
# ['Bhojanalya']          1400
# ['Pub']                 1396
# ['Food Truck']          1289
# ['Microbrewery']         866
# ['Mess']                 611
# ['Paan Shop']            521
# ['Club']                 340
# ['Confectionery']        306
# ['Butcher Shop']         170
# ['Cocktail Bar']          64
# ['Shack']                 44
# ['Irani Cafe']            24
# ['Pop up']                 6
# Name: establishment, dtype: int64

# %%
zomato[zomato.establishment=='[]'].describe()
# Out:
#              res_id  country_id  average_cost_for_two  price_range  \
# count  4.827000e+03      4827.0           4827.000000  4827.000000
# mean   1.660140e+07         1.0            306.090532     1.315931
# std    5.840361e+06         0.0            225.603653     0.518055
# min    3.355000e+03         1.0              0.000000     1.000000
# 25%    1.859872e+07         1.0            150.000000     1.000000
# 50%    1.881219e+07         1.0            250.000000     1.000000
# 75%    1.899007e+07         1.0            400.000000     2.000000
# max    1.915979e+07         1.0           4000.000000     4.000000
#
#        aggregate_rating        votes  photo_count     delivery  takeaway  \
# count       4827.000000  4827.000000  4827.000000  4827.000000    4827.0
# mean           3.202507   226.303294    69.165113    -0.098405      -1.0
# std            1.388746   423.907824   185.458344     0.991077       0.0
# min            0.000000     0.000000     0.000000    -1.000000      -1.0
# 25%            3.100000     5.000000     0.000000    -1.000000      -1.0
# 50%            3.700000    30.000000     6.000000    -1.000000      -1.0
# 75%            4.000000   241.000000    38.000000     1.000000      -1.0
# max            4.900000  3173.000000  1803.000000     1.000000      -1.0
#
#        highlights_count
# count       4827.000000
# mean           4.414543
# std            3.043186
# min            0.000000
# 25%            2.000000
# 50%            5.000000
# 75%            6.000000
# max           20.000000

# %%
zomato.describe()
# Out:
#              res_id  country_id  average_cost_for_two    price_range  \
# count  2.119440e+05    211944.0         211944.000000  211944.000000
# mean   1.349411e+07         1.0            595.812229       1.882535
# std    7.883722e+06         0.0            606.239363       0.892989
# min    5.000000e+01         1.0              0.000000       1.000000
# 25%    3.301027e+06         1.0            250.000000       1.000000
# 50%    1.869573e+07         1.0            400.000000       2.000000
# 75%    1.881297e+07         1.0            700.000000       2.000000
# max    1.915979e+07         1.0          30000.000000       4.000000
#
#        aggregate_rating          votes    photo_count       delivery  \
# count     211944.000000  211944.000000  211944.000000  211944.000000
# mean           3.395937     378.001864     256.971224      -0.255907
# std            1.283642     925.333370     867.668940       0.964172
# min            0.000000     -18.000000       0.000000      -1.000000
# 25%            3.300000      16.000000       3.000000      -1.000000
# 50%            3.800000     100.000000      18.000000      -1.000000
# 75%            4.100000     362.000000     128.000000       1.000000
# max            4.900000   42539.000000   17702.000000       1.000000
#
#        takeaway  highlights_count
# count  211944.0     211944.000000
# mean       -1.0          9.362393
# std         0.0          4.341937
# min        -1.0          0.000000
# 25%        -1.0          6.000000
# 50%        -1.0          9.000000
# 75%        -1.0         11.000000
# max        -1.0         42.000000

# %%
zomato[zomato.establishment=='[]'].groupby('price_range').count()
# Out:
#              res_id  name  establishment  country_id  locality_verbose  \
# price_range
# 1              3416  3416           3416        3416              3416
# 2              1309  1309           1309        1309              1309
# 3                90    90             90          90                90
# 4                12    12             12          12                12
#
#              cuisines  average_cost_for_two  currency  highlights  \
# price_range
# 1                3199                  3416      3416        3416
# 2                1277                  1309      1309        1309
# 3                  90                    90        90          90
# 4                   4                    12        12          12
#
#              aggregate_rating  rating_text  votes  photo_count  delivery  \
# price_range
# 1                        3416         3416   3416         3416      3416
# 2                        1309         1309   1309         1309      1309
# 3                          90           90     90           90        90
# 4                          12           12     12           12        12
#
#              takeaway  highlights_count
# price_range
# 1                3416              3416
# 2                1309              1309
# 3                  90                90
# 4                  12                12

# %%
for i in range(1,5): 
    zomato[zomato.price_range==i].establishment.value_counts().plot('barh')
    plt.show()
# Out:
# D:\anaconda\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: `Series.plot()` should not be called with positional arguments, only keyword arguments. The order of positional arguments will change in the future. Use `Series.plot(kind='barh')` instead of `Series.plot('barh',)`.

# %% [markdown]
# #### Given the above analysis, it is clear that for different resturants which do not have a establishment type, we can replace them with the mode in price range 1 and 2 and drop them in price range 3 and 4

# %%
p1=zomato[((zomato.establishment=='[]') & (zomato.price_range==1))].establishment.index
p2=zomato[((zomato.establishment=='[]') & (zomato.price_range==2))].establishment.index

# %%
for i in p1:
    zomato['establishment'][i]="['Quick Bites']"
for i in p2:
    zomato['establishment'][i]="['Casual Dining']"
# Out:
# D:\anaconda\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# D:\anaconda\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
zomato=zomato.drop(zomato[zomato.establishment=='[]'].index)

# %%
zomato.establishment.value_counts()
# Out:
# ['Quick Bites']        67806
# ['Casual Dining']      63117
# ['Café']               22760
# ['Bakery']              8282
# ['Dessert Parlour']     7961
# ['Bar']                 6553
# ['Fine Dining']         6401
# ['Sweet Shop']          6103
# ['Beverage Shop']       5571
# ['Dhaba']               2939
# ['Lounge']              2761
# ['Food Court']          2722
# ['Kiosk']               1829
# ['Bhojanalya']          1400
# ['Pub']                 1396
# ['Food Truck']          1289
# ['Microbrewery']         866
# ['Mess']                 611
# ['Paan Shop']            521
# ['Club']                 340
# ['Confectionery']        306
# ['Butcher Shop']         170
# ['Cocktail Bar']          64
# ['Shack']                 44
# ['Irani Cafe']            24
# ['Pop up']                 6
# Name: establishment, dtype: int64

# %%
zomato.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 211842 entries, 0 to 211943
# Data columns (total 17 columns):
# res_id                  211842 non-null int64
# name                    211842 non-null object
# establishment           211842 non-null object
# country_id              211842 non-null int64
# locality_verbose        211842 non-null object
# cuisines                210459 non-null object
# average_cost_for_two    211842 non-null int64
# price_range             211842 non-null int64
# currency                211842 non-null object
# highlights              211842 non-null object
# aggregate_rating        211842 non-null float64
# rating_text             211842 non-null object
# votes                   211842 non-null int64
# photo_count             211842 non-null int64
# delivery                211842 non-null int64
# takeaway                211842 non-null int64
# highlights_count        211842 non-null int64
# dtypes: float64(1), int64(9), object(7)
# memory usage: 29.1+ MB

# %%
zomato.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 211842 entries, 0 to 211943
# Data columns (total 17 columns):
# res_id                  211842 non-null int64
# name                    211842 non-null object
# establishment           211842 non-null object
# country_id              211842 non-null int64
# locality_verbose        211842 non-null object
# cuisines                210459 non-null object
# average_cost_for_two    211842 non-null int64
# price_range             211842 non-null int64
# currency                211842 non-null object
# highlights              211842 non-null object
# aggregate_rating        211842 non-null float64
# rating_text             211842 non-null object
# votes                   211842 non-null int64
# photo_count             211842 non-null int64
# delivery                211842 non-null int64
# takeaway                211842 non-null int64
# highlights_count        211842 non-null int64
# dtypes: float64(1), int64(9), object(7)
# memory usage: 29.1+ MB

# %%
zomato=zomato.dropna()

# %%
def cuisines(x):
    x=x.split(",")
    return x
cuisines(zomato.cuisines[0])
# Out:
# ['North Indian', ' South Indian', ' Mithai', ' Street Food', ' Desserts']

# %%
zomato['cuisines']=zomato['cuisines'].apply(cuisines)

# %%
zomato['cuisines_count']=zomato['cuisines'].apply(lambda x: len(x))

# %%
zomato.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 210459 entries, 0 to 211943
# Data columns (total 18 columns):
# res_id                  210459 non-null int64
# name                    210459 non-null object
# establishment           210459 non-null object
# country_id              210459 non-null int64
# locality_verbose        210459 non-null object
# cuisines                210459 non-null object
# average_cost_for_two    210459 non-null int64
# price_range             210459 non-null int64
# currency                210459 non-null object
# highlights              210459 non-null object
# aggregate_rating        210459 non-null float64
# rating_text             210459 non-null object
# votes                   210459 non-null int64
# photo_count             210459 non-null int64
# delivery                210459 non-null int64
# takeaway                210459 non-null int64
# highlights_count        210459 non-null int64
# cuisines_count          210459 non-null int64
# dtypes: float64(1), int64(10), object(7)
# memory usage: 40.5+ MB

# %%
zomato.head()
# Out:
#     res_id                            name      establishment  country_id  \
# 0  3400299                     Bikanervala    ['Quick Bites']           1
# 1  3400005  Mama Chicken Mama Franky House    ['Quick Bites']           1
# 2  3401013                   Bhagat Halwai    ['Quick Bites']           1
# 3  3400290                   Bhagat Halwai    ['Quick Bites']           1
# 4  3401744     The Salt Cafe Kitchen & Bar  ['Casual Dining']           1
#
#     locality_verbose                                           cuisines  \
# 0     Khandari, Agra  [North Indian,  South Indian,  Mithai,  Street...
# 1   Agra Cantt, Agra  [North Indian,  Mughlai,  Rolls,  Chinese,  Fa...
# 2     Shahganj, Agra                               [Fast Food,  Mithai]
# 3  Civil Lines, Agra     [Desserts,  Bakery,  Fast Food,  South Indian]
# 4      Tajganj, Agra             [North Indian,  Continental,  Italian]
#
#    average_cost_for_two  price_range currency  \
# 0                   700            2      Rs.
# 1                   600            2      Rs.
# 2                   300            1      Rs.
# 3                   300            1      Rs.
# 4                  1000            3      Rs.
#
#                                           highlights  aggregate_rating  \
# 0  [Lunch, Takeaway Available, Credit Card, Dinne...               4.4
# 1  [Delivery, No Alcohol Available, Dinner, Takea...               4.4
# 2  [No Alcohol Available, Dinner, Takeaway Availa...               4.2
# 3  [Takeaway Available, Credit Card, Lunch, Deliv...               4.3
# 4  [Lunch, Serves Alcohol, Cash, Credit Card, Din...               4.9
#
#   rating_text  votes  photo_count  delivery  takeaway  highlights_count  \
# 0   Very Good    814          154        -1        -1                 8
# 1   Very Good   1203          161        -1        -1                 7
# 2   Very Good    801          107         1        -1                14
# 3   Very Good    693          157         1        -1                11
# 4   Excellent    470          291         1        -1                27
#
#    cuisines_count
# 0               5
# 1               6
# 2               2
# 3               4
# 4               3

# %%
zomato[['average_cost_for_two','aggregate_rating','photo_count','highlights_count','cuisines_count','votes']].corr()
# Out:
#                       average_cost_for_two  aggregate_rating  photo_count  \
# average_cost_for_two              1.000000          0.227465     0.341523
# aggregate_rating                  0.227465          1.000000     0.218453
# photo_count                       0.341523          0.218453     1.000000
# highlights_count                  0.530316          0.327964     0.364588
# cuisines_count                    0.206535          0.230750     0.198546
# votes                             0.268095          0.271367     0.654681
#
#                       highlights_count  cuisines_count     votes
# average_cost_for_two          0.530316        0.206535  0.268095
# aggregate_rating              0.327964        0.230750  0.271367
# photo_count                   0.364588        0.198546  0.654681
# highlights_count              1.000000        0.364282  0.329440
# cuisines_count                0.364282        1.000000  0.197966
# votes                         0.329440        0.197966  1.000000

# %%
import seaborn as sns

sns.distplot(zomato[zomato['price_range']==1].aggregate_rating, color='red')
sns.distplot(zomato[zomato['price_range']==2].aggregate_rating, color='green')
sns.distplot(zomato[zomato['price_range']==3].aggregate_rating, color='blue')
sns.distplot(zomato[zomato['price_range']==4].aggregate_rating, color='yellow')

# %%
sns.pairplot(zomato[['average_cost_for_two','aggregate_rating','photo_count','highlights_count','cuisines_count','votes','price_range']], hue='price_range')
